# %% [markdown]
# # **Author : Pujayant Kumar**
#
# # **LGMVIP**
#
# # Task-3 : IMAGE TO PENCIL SKETCH WITH PYTHON

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("3D_Wallpapers_002553D.jpg")
#image

# %% [markdown]
# # Reading the Original Image

# %%
image=cv2.imread("/content/3D Wallpapers 00255.jpg")
original_image =cv2.resize(image, (500, 300))
cv2_imshow(original_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7F3DB347F610>

# %% [markdown]
# # Convert the RBG image to grayscale image

# %%
gray_scale_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x7F3DB33A6790>

# %% [markdown]
# # Inverted the grayscale image

# %%
inverted_gray_scale_image = cv2.bitwise_not(gray_scale_image)
cv2_imshow(inverted_gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x7F3DB346E790>

# %% [markdown]
# # Apply a Guassian Blur

# %%
inverted_blurry_image = cv2.GaussianBlur(inverted_gray_scale_image, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(inverted_blurry_image)
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x7F3DB33B0ED0>

# %% [markdown]
# # Mixing the gray scale image with inverted blurry image

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_pencil_sketch_image = dodgeV2(gray_scale_image,inverted_blurry_image)

cv2_imshow(final_pencil_sketch_image )
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x7F3DB348AC50>

# %% [markdown]
# # Original image and pencil sketch image

# %%
cv2_imshow(original_image)

cv2_imshow(final_pencil_sketch_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7F3DB33A6B50>
# <PIL.Image.Image image mode=L size=500x300 at 0x7F3DB33A6AD0>

# %% [markdown]
# # **Thank You**
